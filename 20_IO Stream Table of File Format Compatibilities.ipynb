# %% [markdown]
# ### IO Streams File Format Compatibilities

# %% [raw]
# <TarInfo 'WOA13_annual_SST_nc3_64bitdata.nc' at 0x18153c6368>
# Not compatible with netcdf
# Not compatible with netcdf4
# Not compatible with h5netcdf
# Not compatible with xarray
#
# <TarInfo 'WOA13_annual_SST_nc3_64bitoffset.nc' at 0x18153c6430>
# Compatible with netcdf
# Not compatible with netcdf4
# Not compatible with h5netcdf
# Compatible with xarray
#
# <TarInfo 'WOA13_annual_SST_nc3_classic.nc' at 0x18153c64f8>
# Compatible with netcdf
# Not compatible with netcdf4
# Not compatible with h5netcdf
# Compatible with xarray
#
# <TarInfo 'WOA13_annual_SST_nc4_classic.nc' at 0x18153c65c0>
# Not compatible with netcdf
# Not compatible with netcdf4
# Not compatible with h5netcdf
# Not compatible with xarray
#
# <TarInfo 'WOA13_annual_SST_nc4.nc' at 0x18153c6688>
# Not compatible with netcdf
# Not compatible with netcdf4
# Not compatible with h5netcdf
# Not compatible with xarray

# %% [markdown]
# 5 files in the tar and 4 modules tested against

# %%
# %%HTML
# <head>
# <style>
# table {
#     font-family: roboto, sans-serif;
#     border-collapse: collapse;
#     width: 100%;
# }
#
# td, th {
#     border: 1px solid #dddddd;
#     text-align: left;
#     padding: 8px;
# }
#
# tr {
#     align: right;
# }
#
# tr:nth-child(1) {
#     background-color: #dddddd;
# }
#
# #file {
#     text-align: left !important;
# }
# </style>
# </head>
# <body>
#
# <table>
#   <tr>
#     <th id="file">File</th>
#     <th>netCDF</th>
#     <th>netCDF4</th>
#     <th>h5netCDF</th>
#     <th>xarray</th>
#   </tr>
#   <tr>
#     <td id="file">WOA13_annual_SST_nc3_64bitdata.nc</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#   </tr>
#   <tr>
#     <td id="file">WOA13_annual_SST_nc3_64bitoffset.nc</td>
#     <td>Compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Compatible</td>
#   </tr>
#   <tr>
#     <td id="file">WOA13_annual_SST_nc3_classic.nc</td>
#     <td>Compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Compatible</td>
#   </tr>
#   <tr>
#     <td id="file">WOA13_annual_SST_nc4_classic.nc</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#   </tr>
#   <tr>
#     <td id="file">WOA13_annual_SST_nc4.nc</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#   </tr>
# </table>
#
# </body>
# Out:
# <head>
# <style>
# table {
#     font-family: roboto, sans-serif;
#     border-collapse: collapse;
#     width: 100%;
# }
#
# td, th {
#     border: 1px solid #dddddd;
#     text-align: left;
#     padding: 8px;
# }
#
# tr {
#     align: right;
# }
#
# tr:nth-child(1) {
#     background-color: #dddddd;
# }
#
# #file {
#     text-align: left !important;
# }
# </style>
# </head>
# <body>
#
# <table>
#   <tr>
#     <th id="file">File</th>
#     <th>netCDF</th>
#     <th>netCDF4</th>
#     <th>h5netCDF</th>
#     <th>xarray</th>
#   </tr>
#   <tr>
#     <td id="file">WOA13_annual_SST_nc3_64bitdata.nc</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#   </tr>
#   <tr>
#     <td id="file">WOA13_annual_SST_nc3_64bitoffset.nc</td>
#     <td>Compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Compatible</td>
#   </tr>
#   <tr>
#     <td id="file">WOA13_annual_SST_nc3_classic.nc</td>
#     <td>Compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Compatible</td>
#   </tr>
#   <tr>
#     <td id="file">WOA13_annual_SST_nc4_classic.nc</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#   </tr>
#   <tr>
#     <td id="file">WOA13_annual_SST_nc4.nc</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#     <td>Not compatible</td>
#   </tr>
# </table>
#
# </body>
